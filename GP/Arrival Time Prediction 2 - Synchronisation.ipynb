# %% [markdown]
# # Arrival Time Prediction - Synchronisation
# This notebook is the second on the work on GP regression for arrival time prediction. The goal of this one is to estimate a function for each segment that synchonises the progress of all trajectories. This needs to be done so that predictions can be made based on a new trajectory and not a single data point.
#
# The synchonisation function will be estimated using a GP, which we are all familiar now by now. First off, let's get some libraries into scope, set the seed and load the data that was pickled in the first notebook.

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns
import pandas as pd
import scipy.stats as stats 
import math
import plot
import GPy
import gp_gpy as gp
import synch

version = 3
train = pd.read_pickle('train.pkl')
support = pd.read_pickle('support.pkl')
route_n = 3
traj_n = 7
sns.set(style="darkgrid")
np.random.seed(1)

# %% [markdown]
# ## Hyperparameter Priors
# The synchronisation function is a function $f : \mathcal{R}^2 \mapsto [0, 1]$ so we will use a bivariate GP model. Let's look at some priors for the hyperparameters kernel lengthscale, kernel variance and likelihood variance.

# %% [markdown]
# ### Kernel Lenghtscale ($l$)
# When the data was downsampled in the pre processing, it was done with $\delta = 3*10^{-2}$. Based on this we have implicitly said that points that have a distance of delta are close by, so the lengthscale prior should reflect that.
#
# Since GPFlow is quite a minimalistic library (that is: a bit buggy, and poorly documented), there is no way of plotting kernel functions, and the function to compute covariance matrices at all, `k.compute_K`, seem to be busted beyond belief. Plotting will have to be done by implementing the function by oneself and using it for plotting. Thus you find an implementation of the RBF kernel function below.
#
# The goal is to find an $l$ of the RBF that makes it wide enough to consider points within delta distance as close. Trying some different values shows that $l = 0.25$ gives something that would consider the closest $10$ points close and then decay noticeably.

# %%
def rbf(X, x, var, l):
      return var*np.exp(-(abs(X-x)*abs(X-x))/(2*math.pow(l, 2)))

xmin = 0
xmax = 1
xx = np.linspace(xmin, xmax, 100)[:,None]
sns.lineplot(x=xx[:,0], y = rbf(xx, 0, 1, 0.25)[:,0])

# %% [markdown]
# Having concluded a value of $l$ that makes sense, we now put a distribution over it with mean around the chosen value and a variance representing our certainty. I am not too certain in my belief, and believe that $l$ could take on values quite a bit bigger than the mean value. Since the length scale is strictly positive I've chosen a gamma distribution, which it can be seen in the plot below. This is our length scale prior!

# %%
xmin = 0
xmax = 0.5
l_alpha = 2.5
l_theta = 0.1
xx = np.linspace(xmin, xmax, 100)[:,None]
y = stats.gamma.pdf(xx, a=l_alpha, scale=l_theta)
sns.lineplot(x = xx[:,0], y = y[:,0])

# %% [markdown]
# ### Kernel Variance ($\sigma_f$)
# The kernel variance determines the average distance that the function output has from the function mean. Since the output of the function is on $[0, 1]$, the output should not need to vary more than this. To prevent overfitting a $\sigma_f = 0.6$ seems right, but let's go with quite high uncertainty on this one. Since it is also a strictly positive quantity a gamma distribution is used here as well, like with the lengthscale.

# %%
xmin = 0
xmax = 2
sigmaf_alpha = 75
sigmaf_theta = 0.01
xx = np.linspace(xmin, xmax, 100)[:,None]
y = stats.gamma.pdf(xx, a=sigmaf_alpha, scale=sigmaf_theta)
sns.lineplot(x = xx[:,0], y = y[:,0])

# %% [markdown]
# ### Likelihood Variance ($\sigma$)
# We also need to chose a prior for the likelihood variance $\sigma$, which representas the measurement noise. This model will assume a static variance, even though we know that it depends on where in the city you are. In mode dense areas the GPS accuracy suffers a bit while it works well in more rural areas. A seperate model for the GPS variance estimation should be used if this was done properly.
#
# In the provided thesis the average GPS variance of a smartphone is claimed to be $\sigma = 10^-5$ so we'll go with that, but like with $\sigma_f$ we will be quite uncertain.

# %%
xmin = 0
xmax = 0.0001
sigma_alpha = 10
sigma_theta = 0.000001
xx = np.linspace(xmin, xmax, 100)[:,None]
y = stats.gamma.pdf(xx, a=sigma_alpha, scale=sigma_theta)
sns.lineplot(x = xx[:,0], y = y[:,0])

# %%
d_lat = train.lat.max() - train.lat.min()
d_lon = train.lon.max() - train.lon.min()
print(d_lat, d_lon)
# Out:
# 0.047312736511198494 0.00957489013679691

# %% [markdown]
# ## Mean time_left
# Started to figure out mean time_left trajectory for each segment

# %%
print(train.traj.unique())

segments = {}

curr_seg = 0
for x in train.itertuples():
    if x.seg != curr_seg:
        #print(x)
        
        tup = (x.time_left, x.traj)
        
        if x.seg in segments:
            segments[x.seg].append(tup)
        else:
            segments[x.seg] = [tup]
        
        curr_seg = x.seg
        
#print(segments)
        
for s, traj_list in segments.items():
    traj_list.sort()
    print(traj_list)
# Out:
# [  24   79   82   95  109  123  227  228  233  281  320  339  346  355
#   385  390  412  445  486  516  522  550  577  598  627  636  695  706
#   718  838  868  896  907  953 1029 1045 1070 1073 1104 1113 1127 1133
#  1165 1166 1167 1187 1228 1276 1309 1332 1355 1422 1441 1447 1499 1526
#  1546 1590 1609 1628 1640 1645 1662 1675 1704 1737 1760 1765 1802 1818
#  1827 1828 1830 1851 1855 1892 1904 1906 1913 1914 1937 1983 2008 2015
#  2116 2118 2151 2168 2187 2189 2198 2203 2211 2237 2258 2297 2308 2347
#  2353 2384 2388 2422 2479 2483 2492 2501 2630 2667 2669 2670 2703 2707
#  2724 2806 2817 2840 2841 2855 2861 2866 2877 2886 2903 2976 2991 3053
#  3133 3187 3188 3206 3207 3213 3221 3249 3278 3299 3361 3370 3376 3379
#  3385 3393 3395 3419 3422 3436 3449 3474 3504 3556 3561 3575 3592 3595
#  3622]
# [(22.0, 1104), (24.0, 1165), (24.0, 1904), (25.0, 522), (26.0, 896), (26.0, 2866), (27.0, 2353), (28.0, 1645), (28.0, 2991), (30.0, 3622), (31.0, 1737), (31.0, 3419), (32.0, 2258), (33.0, 82), (33.0, 3575), (34.0, 695), (34.0, 3449), (34.0, 3561), (37.0, 3299), (38.0, 1499), (38.0, 1818), (38.0, 1830), (38.0, 2501), (40.0, 339), (40.0, 2211), (40.0, 2479), (40.0, 2630), (41.0, 1760), (42.0, 3221), (43.0, 445), (43.0, 1441), (43.0, 3278), (44.0, 550), (44.0, 2347), (45.0, 3422), (45.0, 3504), (46.0, 79), (46.0, 385), (46.0, 627), (46.0, 1073), (46.0, 1276), (47.0, 486), (47.0, 1332), (47.0, 1422), (47.0, 2483), (47.0, 2724), (48.0, 109), (48.0, 320), (48.0, 1166), (48.0, 1546), (49.0, 95), (49.0, 1802), (49.0, 2203), (49.0, 3370), (50.0, 577), (50.0, 1187), (51.0, 281), (51.0, 706), (51.0, 2237), (51.0, 2841), (51.0, 2855), (51.0, 2976), (51.0, 3436), (52.0, 412), (52.0, 1167), (52.0, 1590), (52.0, 1906), (52.0, 2667), (52.0, 3133), (52.0, 3556), (52.0, 3595), (53.0, 1133), (53.0, 1851), (53.0, 2168), (53.0, 2189), (54.0, 233), (54.0, 718), (54.0, 1937), (54.0, 3053), (54.0, 3385), (55.0, 2297), (55.0, 2422), (55.0, 2840), (55.0, 3361), (55.0, 3393), (55.0, 3395), (56.0, 24), (56.0, 228), (56.0, 907), (56.0, 1447), (56.0, 2703), (57.0, 1029), (57.0, 1228), (57.0, 1628), (57.0, 1855), (57.0, 1914), (57.0, 1983), (57.0, 2817), (57.0, 3207), (57.0, 3249), (57.0, 3379), (58.0, 2669), (58.0, 2861), (59.0, 346), (59.0, 636), (59.0, 2187), (59.0, 2903), (60.0, 1113), (60.0, 1127), (60.0, 1675), (61.0, 1662), (61.0, 1892), (61.0, 2492), (62.0, 598), (62.0, 1355), (62.0, 2116), (62.0, 2198), (62.0, 2806), (62.0, 3187), (63.0, 355), (63.0, 390), (63.0, 953), (63.0, 1640), (63.0, 2118), (63.0, 3592), (64.0, 1045), (64.0, 1070), (64.0, 1309), (64.0, 1704), (64.0, 1913), (64.0, 3213), (65.0, 227), (66.0, 2707), (66.0, 3474), (67.0, 2670), (67.0, 2877), (68.0, 2151), (69.0, 1609), (69.0, 2388), (70.0, 516), (70.0, 1526), (71.0, 2886), (72.0, 868), (72.0, 2015), (73.0, 838), (73.0, 3376), (75.0, 1828), (75.0, 2384), (79.0, 3188), (80.0, 1827), (81.0, 1765), (83.0, 123), (88.0, 2008), (89.0, 3206), (96.0, 2308)]
# [(31.0, 1165), (32.0, 627), (32.0, 1818), (33.0, 1104), (33.0, 1760), (33.0, 1904), (33.0, 3385), (34.0, 320), (34.0, 2353), (35.0, 3395), (35.0, 3595), (36.0, 3504), (37.0, 2347), (37.0, 3278), (37.0, 3419), (38.0, 412), (40.0, 1167), (40.0, 3053), (40.0, 3575), (40.0, 3622), (42.0, 1851), (43.0, 516), (43.0, 1166), (43.0, 2630), (44.0, 390), (44.0, 695), (44.0, 1447), (44.0, 3449), (44.0, 3561), (45.0, 95), (45.0, 123), (45.0, 706), (45.0, 1127), (45.0, 1765), (45.0, 2841), (45.0, 3207), (45.0, 3379), (46.0, 1441), (46.0, 1830), (46.0, 2015), (46.0, 2479), (47.0, 228), (47.0, 1422), (47.0, 1526), (47.0, 2886), (47.0, 3299), (48.0, 227), (48.0, 1228), (48.0, 1628), (48.0, 1675), (48.0, 2008), (48.0, 2501), (48.0, 2976), (48.0, 3187), (49.0, 486), (49.0, 896), (49.0, 2203), (49.0, 2388), (49.0, 2492), (49.0, 3188), (49.0, 3213), (49.0, 3221), (49.0, 3422), (50.0, 355), (50.0, 1309), (50.0, 1662), (50.0, 1828), (50.0, 2116), (50.0, 2483), (51.0, 445), (51.0, 598), (51.0, 1045), (51.0, 2118), (51.0, 2724), (51.0, 2866), (52.0, 1590), (52.0, 2151), (52.0, 2187), (52.0, 2211), (52.0, 2669), (52.0, 3361), (53.0, 1914), (53.0, 2817), (53.0, 3592), (54.0, 82), (54.0, 718), (54.0, 907), (54.0, 1906), (54.0, 2384), (54.0, 3249), (55.0, 550), (55.0, 1070), (55.0, 1276), (55.0, 2703), (55.0, 2806), (55.0, 2903), (55.0, 3436), (56.0, 346), (56.0, 1187), (56.0, 1546), (56.0, 1737), (56.0, 1802), (56.0, 1827), (56.0, 2198), (56.0, 2667), (56.0, 2670), (56.0, 3556), (57.0, 1499), (57.0, 2237), (57.0, 2877), (57.0, 3370), (58.0, 79), (58.0, 1029), (58.0, 1855), (58.0, 1913), (58.0, 1983), (58.0, 2258), (58.0, 2308), (58.0, 2707), (58.0, 2861), (59.0, 109), (59.0, 636), (59.0, 868), (59.0, 2189), (60.0, 339), (60.0, 522), (60.0, 953), (60.0, 2297), (60.0, 2840), (61.0, 24), (61.0, 1640), (61.0, 3206), (62.0, 577), (62.0, 1073), (62.0, 1704), (62.0, 1892), (62.0, 2422), (63.0, 2168), (63.0, 2991), (63.0, 3133), (63.0, 3376), (64.0, 1355), (65.0, 1332), (65.0, 1609), (65.0, 1645), (65.0, 3474), (66.0, 1937), (67.0, 1113), (68.0, 838), (69.0, 281), (71.0, 2855), (73.0, 3393), (74.0, 1133), (76.0, 233), (85.0, 385)]
# [(19.0, 3422), (20.0, 320), (20.0, 627), (20.0, 896), (20.0, 1104), (20.0, 1165), (20.0, 1760), (20.0, 1904), (20.0, 2203), (20.0, 2483), (20.0, 3561), (21.0, 706), (21.0, 1737), (21.0, 1765), (21.0, 1818), (21.0, 1830), (21.0, 1914), (21.0, 2724), (21.0, 3206), (21.0, 3395), (22.0, 1447), (22.0, 2976), (22.0, 3187), (22.0, 3361), (22.0, 3385), (22.0, 3575), (23.0, 1906), (23.0, 2703), (23.0, 3207), (23.0, 3221), (23.0, 3419), (23.0, 3436), (23.0, 3504), (24.0, 636), (24.0, 1127), (24.0, 2116), (24.0, 2118), (24.0, 2841), (24.0, 3556), (25.0, 907), (25.0, 2187), (25.0, 2353), (25.0, 2670), (25.0, 2903), (25.0, 3595), (26.0, 868), (26.0, 1187), (26.0, 1228), (26.0, 1628), (26.0, 1855), (26.0, 2168), (26.0, 2707), (26.0, 3278), (27.0, 82), (27.0, 1309), (27.0, 1892), (27.0, 2630), (27.0, 2855), (27.0, 2991), (27.0, 3133), (27.0, 3622), (29.0, 695), (29.0, 1166), (29.0, 2492), (29.0, 2667), (29.0, 3592), (30.0, 109), (30.0, 2501), (30.0, 3393), (31.0, 2422), (32.0, 227), (32.0, 339), (34.0, 79), (36.0, 346), (36.0, 390), (36.0, 1113), (37.0, 486), (37.0, 1851), (38.0, 2198), (38.0, 2886), (39.0, 2015), (39.0, 2840), (39.0, 3376), (39.0, 3379), (40.0, 228), (40.0, 2388), (40.0, 2479), (40.0, 3213), (41.0, 1073), (41.0, 1704), (42.0, 1276), (42.0, 2237), (42.0, 3053), (43.0, 281), (43.0, 1675), (43.0, 2669), (44.0, 445), (44.0, 1827), (44.0, 2308), (45.0, 1526), (45.0, 2806), (46.0, 1045), (46.0, 1645), (46.0, 1937), (46.0, 2211), (46.0, 2384), (46.0, 2817), (46.0, 3299), (47.0, 412), (47.0, 1332), (47.0, 1499), (47.0, 1609), (47.0, 1662), (47.0, 1828), (47.0, 3449), (48.0, 355), (48.0, 550), (48.0, 1133), (48.0, 1355), (48.0, 2151), (48.0, 2297), (48.0, 3249), (49.0, 95), (49.0, 1983), (49.0, 3370), (49.0, 3474), (50.0, 577), (50.0, 1546), (50.0, 2258), (51.0, 24), (51.0, 123), (51.0, 1167), (51.0, 2189), (51.0, 2866), (51.0, 3188), (52.0, 1422), (52.0, 1802), (53.0, 233), (53.0, 385), (53.0, 516), (53.0, 838), (53.0, 953), (53.0, 1029), (53.0, 1640), (53.0, 2861), (54.0, 718), (54.0, 1441), (54.0, 1913), (54.0, 2347), (55.0, 1590), (58.0, 1070), (59.0, 2877), (65.0, 598), (66.0, 2008), (71.0, 522)]
# [(37.0, 339), (37.0, 3422), (38.0, 486), (38.0, 896), (39.0, 1760), (40.0, 320), (40.0, 627), (40.0, 1165), (41.0, 1818), (42.0, 390), (42.0, 1104), (42.0, 1276), (42.0, 1830), (42.0, 1914), (44.0, 1447), (44.0, 1662), (44.0, 2116), (44.0, 2203), (44.0, 2669), (44.0, 2806), (44.0, 2866), (44.0, 3053), (45.0, 228), (45.0, 281), (45.0, 412), (45.0, 953), (45.0, 2237), (45.0, 2388), (45.0, 2886), (45.0, 3376), (45.0, 3575), (46.0, 706), (46.0, 1422), (46.0, 1499), (46.0, 1913), (46.0, 2353), (46.0, 2483), (46.0, 3206), (46.0, 3361), (46.0, 3395), (46.0, 3504), (46.0, 3622), (47.0, 577), (47.0, 1355), (47.0, 1645), (47.0, 1904), (47.0, 2151), (47.0, 2189), (47.0, 2198), (47.0, 2817), (48.0, 82), (48.0, 445), (48.0, 636), (48.0, 1127), (48.0, 1765), (48.0, 2840), (48.0, 3436), (48.0, 3561), (49.0, 123), (49.0, 1526), (49.0, 1737), (49.0, 2670), (49.0, 2703), (49.0, 3133), (49.0, 3213), (49.0, 3419), (49.0, 3595), (50.0, 109), (50.0, 2347), (50.0, 2479), (50.0, 2991), (50.0, 3299), (50.0, 3474), (51.0, 355), (51.0, 550), (51.0, 1073), (51.0, 1167), (51.0, 1675), (51.0, 1828), (51.0, 3393), (52.0, 695), (52.0, 718), (52.0, 1906), (52.0, 3187), (52.0, 3207), (53.0, 868), (53.0, 1609), (53.0, 2667), (54.0, 79), (54.0, 2492), (54.0, 2501), (54.0, 2855), (54.0, 3592), (55.0, 385), (55.0, 2008), (55.0, 2841), (55.0, 3370), (56.0, 1640), (56.0, 2015), (56.0, 2187), (56.0, 3379), (57.0, 233), (57.0, 3556), (58.0, 3385), (58.0, 3449), (59.0, 516), (59.0, 1546), (59.0, 3249), (60.0, 346), (60.0, 1029), (60.0, 1166), (60.0, 1855), (60.0, 2724), (60.0, 3278), (61.0, 1113), (61.0, 1441), (61.0, 1802), (61.0, 2630), (61.0, 2861), (61.0, 2903), (62.0, 227), (62.0, 1590), (62.0, 1851), (62.0, 2211), (62.0, 2976), (63.0, 522), (63.0, 838), (63.0, 1827), (63.0, 2258), (64.0, 907), (64.0, 1187), (64.0, 2297), (65.0, 24), (65.0, 2308), (65.0, 2707), (66.0, 1045), (66.0, 1133), (66.0, 1892), (68.0, 1309), (68.0, 1937), (69.0, 598), (69.0, 1704), (69.0, 2877), (71.0, 1983), (71.0, 2384), (71.0, 3188), (73.0, 95), (74.0, 1228), (74.0, 1332), (74.0, 2422), (75.0, 2118), (78.0, 1070), (82.0, 1628), (85.0, 2168), (93.0, 3221)]
# [(30.0, 339), (35.0, 2724), (37.0, 1645), (38.0, 1827), (39.0, 2187), (39.0, 2483), (39.0, 3376), (40.0, 953), (40.0, 1737), (40.0, 2347), (41.0, 1546), (41.0, 3422), (42.0, 1187), (43.0, 627), (43.0, 3278), (43.0, 3395), (43.0, 3436), (44.0, 95), (44.0, 3622), (45.0, 1309), (50.0, 896), (51.0, 385), (51.0, 1851), (51.0, 3575), (52.0, 228), (52.0, 1441), (52.0, 1818), (52.0, 2388), (52.0, 2840), (52.0, 3206), (53.0, 320), (53.0, 1127), (53.0, 1228), (53.0, 2492), (54.0, 2151), (54.0, 2703), (55.0, 1355), (55.0, 1422), (55.0, 1913), (55.0, 2384), (56.0, 346), (56.0, 1167), (56.0, 3561), (57.0, 1906), (57.0, 2116), (57.0, 2479), (57.0, 2501), (57.0, 2670), (57.0, 2861), (57.0, 3419), (57.0, 3504), (58.0, 109), (58.0, 706), (58.0, 2630), (58.0, 3188), (58.0, 3592), (59.0, 412), (59.0, 1760), (59.0, 2976), (59.0, 3053), (59.0, 3556), (60.0, 123), (60.0, 522), (60.0, 1765), (60.0, 3299), (60.0, 3370), (62.0, 1166), (62.0, 1499), (62.0, 2211), (63.0, 1276), (63.0, 1855), (63.0, 1914), (63.0, 2008), (63.0, 2877), (64.0, 868), (64.0, 1830), (64.0, 3361), (64.0, 3379), (64.0, 3385), (65.0, 1590), (65.0, 1983), (65.0, 2308), (65.0, 2707), (65.0, 2817), (66.0, 1447), (66.0, 2189), (67.0, 1133), (67.0, 2667), (68.0, 1029), (68.0, 1704), (69.0, 516), (69.0, 1104), (69.0, 2855), (69.0, 3595), (70.0, 1904), (71.0, 281), (72.0, 24), (72.0, 390), (72.0, 1113), (72.0, 2297), (72.0, 2669), (72.0, 2886), (72.0, 2903), (73.0, 227), (73.0, 486), (73.0, 695), (73.0, 2015), (73.0, 2258), (73.0, 2841), (74.0, 2806), (74.0, 3249), (75.0, 1045), (75.0, 1165), (75.0, 1609), (76.0, 355), (76.0, 1628), (76.0, 1828), (76.0, 2353), (76.0, 2866), (76.0, 3449), (77.0, 79), (77.0, 445), (78.0, 82), (78.0, 577), (78.0, 2118), (78.0, 2203), (79.0, 1070), (79.0, 2198), (80.0, 907), (81.0, 1526), (81.0, 1675), (81.0, 2991), (81.0, 3187), (81.0, 3221), (82.0, 1640), (82.0, 3133), (83.0, 2168), (83.0, 3207), (85.0, 636), (85.0, 3213), (86.0, 1332), (88.0, 718), (88.0, 1802), (89.0, 1892), (90.0, 2237), (91.0, 1937), (95.0, 233), (96.0, 2422), (99.0, 3474), (104.0, 1662), (107.0, 550), (110.0, 3393), (112.0, 1073), (121.0, 598), (132.0, 838)]
# [(53.0, 1165), (53.0, 3422), (55.0, 390), (55.0, 896), (56.0, 3207), (57.0, 516), (57.0, 2118), (57.0, 3221), (58.0, 2841), (60.0, 24), (60.0, 1904), (60.0, 2237), (60.0, 3361), (60.0, 3379), (61.0, 486), (61.0, 550), (61.0, 1104), (61.0, 1441), (61.0, 1447), (61.0, 2479), (61.0, 3249), (62.0, 228), (62.0, 320), (62.0, 1526), (62.0, 1851), (62.0, 2353), (63.0, 445), (63.0, 1045), (63.0, 1609), (63.0, 1662), (63.0, 1760), (63.0, 2168), (63.0, 2806), (63.0, 2817), (63.0, 2840), (63.0, 2877), (63.0, 2991), (63.0, 3206), (63.0, 3595), (64.0, 636), (64.0, 695), (64.0, 838), (64.0, 868), (64.0, 1499), (64.0, 2297), (64.0, 2388), (64.0, 2903), (64.0, 3213), (64.0, 3419), (64.0, 3561), (65.0, 233), (65.0, 1228), (65.0, 1590), (65.0, 2669), (65.0, 2866), (65.0, 3370), (66.0, 1029), (66.0, 1830), (66.0, 1937), (66.0, 2151), (66.0, 2630), (67.0, 79), (67.0, 577), (67.0, 1167), (67.0, 1704), (67.0, 1802), (67.0, 2189), (67.0, 2258), (67.0, 3376), (68.0, 907), (68.0, 1640), (68.0, 1828), (68.0, 1892), (68.0, 2203), (68.0, 2211), (68.0, 3187), (68.0, 3385), (69.0, 109), (69.0, 627), (70.0, 1422), (70.0, 1675), (70.0, 2667), (71.0, 355), (71.0, 706), (71.0, 718), (71.0, 1628), (71.0, 1906), (71.0, 2422), (71.0, 3393), (72.0, 1113), (72.0, 1355), (72.0, 2861), (72.0, 3592), (73.0, 227), (73.0, 3278), (74.0, 2724), (74.0, 3449), (74.0, 3474), (74.0, 3504), (75.0, 82), (75.0, 346), (75.0, 1187), (75.0, 1332), (75.0, 1913), (75.0, 2187), (76.0, 1855), (76.0, 2670), (76.0, 2976), (77.0, 1070), (77.0, 2015), (78.0, 1073), (78.0, 2501), (78.0, 3053), (79.0, 385), (79.0, 598), (79.0, 2703), (80.0, 281), (80.0, 2008), (80.0, 3556), (81.0, 339), (81.0, 953), (81.0, 1127), (81.0, 1276), (82.0, 3188), (83.0, 1166), (83.0, 1765), (83.0, 1914), (84.0, 1737), (84.0, 2308), (85.0, 95), (85.0, 1645), (86.0, 1133), (86.0, 1309), (86.0, 1818), (86.0, 3436), (87.0, 2347), (87.0, 2707), (87.0, 2886), (89.0, 2855), (89.0, 3299), (90.0, 1546), (91.0, 2384), (91.0, 2483), (91.0, 3133), (92.0, 412), (93.0, 3622), (95.0, 1827), (95.0, 2492), (100.0, 1983), (104.0, 123), (104.0, 3395), (106.0, 3575), (124.0, 2116), (140.0, 2198), (143.0, 522)]
# [(21.0, 1818), (21.0, 2116), (22.0, 1104), (22.0, 1165), (22.0, 2198), (22.0, 3422), (23.0, 516), (23.0, 896), (23.0, 1447), (23.0, 2203), (23.0, 2211), (23.0, 3376), (24.0, 228), (24.0, 1133), (24.0, 1228), (24.0, 1422), (24.0, 2667), (24.0, 2806), (24.0, 2841), (24.0, 2877), (24.0, 2976), (24.0, 3207), (24.0, 3622), (25.0, 390), (25.0, 1127), (25.0, 1167), (25.0, 1802), (25.0, 1983), (25.0, 3053), (25.0, 3556), (25.0, 3595), (26.0, 79), (26.0, 95), (26.0, 1906), (26.0, 2237), (26.0, 2353), (26.0, 2388), (26.0, 2840), (26.0, 2903), (26.0, 3221), (27.0, 1309), (27.0, 1441), (27.0, 1590), (27.0, 1640), (27.0, 1675), (27.0, 2297), (27.0, 2703), (27.0, 3206), (27.0, 3278), (27.0, 3393), (28.0, 24), (28.0, 868), (28.0, 1073), (28.0, 1355), (28.0, 1760), (28.0, 1851), (28.0, 2479), (28.0, 2630), (28.0, 2855), (28.0, 3213), (28.0, 3419), (29.0, 1904), (29.0, 2501), (30.0, 1499), (30.0, 3133), (30.0, 3370), (30.0, 3379), (31.0, 2492), (32.0, 1029), (34.0, 1166), (35.0, 227), (35.0, 339), (36.0, 82), (37.0, 1276), (38.0, 346), (38.0, 2670), (39.0, 486), (39.0, 3249), (39.0, 3592), (40.0, 233), (40.0, 1765), (41.0, 385), (41.0, 1546), (41.0, 2669), (41.0, 2866), (42.0, 718), (42.0, 1187), (42.0, 1892), (42.0, 1913), (42.0, 2817), (42.0, 2886), (42.0, 3361), (42.0, 3474), (43.0, 320), (43.0, 550), (43.0, 1914), (44.0, 627), (44.0, 1937), (44.0, 2724), (44.0, 3449), (45.0, 577), (45.0, 598), (45.0, 907), (45.0, 1628), (45.0, 1645), (45.0, 2189), (45.0, 2483), (45.0, 2861), (46.0, 355), (46.0, 1662), (46.0, 1855), (47.0, 109), (47.0, 953), (47.0, 3385), (48.0, 636), (48.0, 2015), (48.0, 2118), (48.0, 2168), (48.0, 3504), (48.0, 3561), (49.0, 838), (49.0, 1827), (49.0, 2422), (49.0, 3575), (50.0, 1526), (50.0, 2151), (50.0, 2707), (51.0, 706), (51.0, 1609), (51.0, 1737), (52.0, 1113), (52.0, 1704), (52.0, 1828), (52.0, 2258), (53.0, 2187), (54.0, 412), (54.0, 1045), (54.0, 3187), (55.0, 695), (57.0, 123), (57.0, 1332), (57.0, 1830), (57.0, 2008), (57.0, 3188), (57.0, 3299), (58.0, 2347), (60.0, 281), (60.0, 3395), (61.0, 3436), (62.0, 1070), (72.0, 2308), (77.0, 522), (92.0, 2384), (103.0, 445), (110.0, 2991)]
# [(109.0, 1165), (111.0, 896), (115.0, 2211), (115.0, 3376), (117.0, 390), (118.0, 339), (119.0, 636), (121.0, 1045), (123.0, 1830), (123.0, 2991), (124.0, 1441), (125.0, 445), (126.0, 412), (126.0, 1704), (126.0, 2187), (126.0, 2483), (127.0, 706), (128.0, 2903), (129.0, 1447), (129.0, 1645), (129.0, 2667), (131.0, 1332), (132.0, 355), (132.0, 695), (132.0, 1104), (133.0, 1802), (133.0, 1818), (133.0, 2189), (134.0, 82), (134.0, 1127), (134.0, 2388), (135.0, 3561), (136.0, 385), (136.0, 627), (136.0, 2806), (137.0, 320), (137.0, 2670), (137.0, 2877), (137.0, 3595), (138.0, 1765), (139.0, 577), (139.0, 907), (139.0, 2118), (139.0, 2866), (140.0, 228), (140.0, 2501), (140.0, 2724), (140.0, 3188), (141.0, 1827), (141.0, 2703), (141.0, 2840), (142.0, 2168), (142.0, 2258), (142.0, 3592), (143.0, 3556), (144.0, 109), (144.0, 1855), (144.0, 3053), (145.0, 346), (145.0, 2198), (146.0, 1228), (146.0, 1828), (146.0, 3299), (146.0, 3370), (147.0, 1914), (148.0, 1609), (148.0, 2297), (148.0, 2308), (149.0, 79), (149.0, 550), (149.0, 718), (149.0, 1851), (149.0, 2630), (149.0, 3385), (150.0, 2015), (150.0, 2151), (150.0, 2203), (150.0, 2353), (151.0, 516), (151.0, 1737), (151.0, 3504), (152.0, 1167), (152.0, 1675), (152.0, 1937), (152.0, 3133), (152.0, 3207), (153.0, 1070), (153.0, 2841), (153.0, 3474), (154.0, 24), (154.0, 281), (154.0, 486), (154.0, 3278), (155.0, 1187), (155.0, 3187), (155.0, 3622), (156.0, 123), (156.0, 227), (157.0, 1546), (157.0, 2237), (157.0, 3449), (158.0, 95), (158.0, 1590), (158.0, 2886), (158.0, 3422), (159.0, 953), (159.0, 1276), (161.0, 1133), (161.0, 3206), (162.0, 3213), (162.0, 3249), (162.0, 3379), (163.0, 598), (163.0, 2422), (165.0, 1355), (165.0, 1983), (165.0, 2492), (166.0, 1628), (166.0, 2347), (166.0, 3575), (167.0, 2855), (167.0, 2976), (169.0, 2479), (169.0, 2861), (171.0, 522), (171.0, 1640), (171.0, 1662), (171.0, 2384), (171.0, 3395), (174.0, 868), (176.0, 1904), (177.0, 2669), (178.0, 2817), (179.0, 233), (179.0, 1309), (179.0, 1906), (179.0, 3436), (180.0, 2707), (180.0, 3419), (181.0, 1760), (183.0, 1166), (187.0, 1073), (197.0, 3361), (198.0, 1913), (199.0, 3221), (200.0, 1892), (201.0, 1422), (207.0, 1113), (212.0, 1029), (216.0, 3393), (230.0, 1499), (231.0, 2116), (234.0, 2008), (282.0, 838), (294.0, 1526)]
# [(36.0, 2187), (37.0, 896), (39.0, 390), (41.0, 95), (41.0, 2669), (41.0, 3206), (43.0, 627), (44.0, 1828), (44.0, 2501), (44.0, 3422), (45.0, 2297), (45.0, 3376), (45.0, 3419), (48.0, 1167), (50.0, 522), (50.0, 3133), (51.0, 577), (51.0, 1704), (52.0, 953), (52.0, 1166), (52.0, 2189), (52.0, 2353), (52.0, 2670), (53.0, 346), (53.0, 1104), (53.0, 1760), (53.0, 2976), (53.0, 3249), (54.0, 228), (54.0, 868), (54.0, 1127), (54.0, 1904), (54.0, 2308), (54.0, 2707), (54.0, 3370), (54.0, 3504), (55.0, 109), (55.0, 1855), (55.0, 2211), (55.0, 2630), (55.0, 2886), (55.0, 3221), (56.0, 123), (56.0, 3556), (57.0, 2422), (58.0, 227), (58.0, 706), (58.0, 2168), (58.0, 2483), (59.0, 838), (59.0, 1113), (59.0, 2866), (60.0, 24), (60.0, 718), (60.0, 2479), (61.0, 1546), (61.0, 2347), (61.0, 2817), (61.0, 2877), (62.0, 550), (62.0, 1332), (62.0, 1675), (62.0, 3188), (63.0, 281), (63.0, 355), (63.0, 412), (63.0, 695), (63.0, 1029), (63.0, 1609), (64.0, 233), (64.0, 1662), (64.0, 2237), (64.0, 2388), (64.0, 3449), (65.0, 598), (65.0, 2118), (65.0, 2991), (66.0, 79), (66.0, 1447), (66.0, 1499), (67.0, 907), (67.0, 2258), (67.0, 2903), (68.0, 1228), (69.0, 486), (69.0, 516), (69.0, 636), (69.0, 1187), (69.0, 1851), (69.0, 2151), (70.0, 1441), (70.0, 1892), (70.0, 1906), (70.0, 3385), (70.0, 3595), (71.0, 1827), (71.0, 2855), (71.0, 3622), (72.0, 1073), (72.0, 1765), (72.0, 1802), (72.0, 3299), (73.0, 1309), (73.0, 1645), (73.0, 2116), (74.0, 1818), (74.0, 2806), (75.0, 339), (75.0, 1422), (75.0, 2008), (75.0, 2703), (75.0, 2841), (75.0, 3053), (75.0, 3379), (76.0, 1165), (76.0, 1737), (77.0, 1355), (77.0, 1983), (77.0, 2198), (77.0, 2861), (77.0, 3561), (78.0, 1914), (78.0, 2724), (79.0, 1070), (79.0, 1937), (79.0, 3187), (80.0, 3474), (80.0, 3592), (81.0, 82), (81.0, 1276), (81.0, 1590), (82.0, 1830), (82.0, 2015), (82.0, 3361), (83.0, 1526), (83.0, 3436), (84.0, 1133), (84.0, 1640), (86.0, 2667), (88.0, 2384), (89.0, 2492), (89.0, 3395), (90.0, 1628), (90.0, 2203), (90.0, 3213), (91.0, 445), (91.0, 1045), (98.0, 3575), (99.0, 3207), (100.0, 2840), (102.0, 385), (105.0, 3393), (106.0, 1913), (110.0, 320), (202.0, 3278)]
# [(30.0, 2187), (33.0, 390), (33.0, 2008), (33.0, 2308), (33.0, 2630), (34.0, 896), (34.0, 2189), (34.0, 2669), (34.0, 2866), (35.0, 1167), (35.0, 1830), (35.0, 1937), (36.0, 3385), (37.0, 385), (38.0, 577), (38.0, 1447), (39.0, 1104), (39.0, 1165), (39.0, 3561), (40.0, 522), (40.0, 1332), (40.0, 1645), (40.0, 2991), (41.0, 1855), (41.0, 2297), (42.0, 445), (42.0, 2168), (42.0, 2670), (43.0, 355), (44.0, 228), (44.0, 1045), (44.0, 1166), (44.0, 3595), (45.0, 3422), (45.0, 3436), (46.0, 95), (46.0, 636), (46.0, 2388), (46.0, 3361), (46.0, 3376), (46.0, 3504), (47.0, 486), (47.0, 1851), (47.0, 1904), (47.0, 2422), (47.0, 2841), (47.0, 2861), (47.0, 2976), (48.0, 695), (48.0, 1546), (48.0, 1640), (48.0, 2806), (48.0, 2877), (49.0, 1628), (49.0, 2703), (49.0, 3187), (49.0, 3207), (49.0, 3213), (50.0, 2118), (50.0, 2237), (50.0, 2258), (50.0, 2817), (51.0, 2151), (52.0, 1609), (52.0, 1760), (52.0, 2855), (52.0, 3249), (52.0, 3278), (53.0, 281), (53.0, 346), (53.0, 1802), (53.0, 2347), (53.0, 3221), (54.0, 1355), (54.0, 2707), (54.0, 3449), (54.0, 3575), (55.0, 598), (55.0, 1827), (56.0, 516), (56.0, 2667), (56.0, 3419), (57.0, 1765), (57.0, 1914), (57.0, 2479), (57.0, 2492), (58.0, 1906), (58.0, 3299), (59.0, 412), (59.0, 953), (59.0, 2903), (60.0, 339), (60.0, 1704), (61.0, 82), (61.0, 1818), (61.0, 2353), (61.0, 2483), (62.0, 123), (62.0, 227), (62.0, 627), (62.0, 1133), (64.0, 79), (64.0, 233), (64.0, 320), (64.0, 1073), (64.0, 1499), (64.0, 1662), (64.0, 2203), (65.0, 550), (65.0, 718), (65.0, 2015), (66.0, 24), (66.0, 109), (66.0, 1441), (66.0, 3053), (66.0, 3393), (66.0, 3556), (67.0, 1422), (67.0, 1913), (68.0, 1526), (69.0, 706), (70.0, 1127), (70.0, 1228), (71.0, 1737), (72.0, 907), (72.0, 1113), (72.0, 1187), (72.0, 1675), (74.0, 2116), (75.0, 1029), (75.0, 3379), (75.0, 3592), (76.0, 1276), (76.0, 1983), (76.0, 2384), (77.0, 2211), (77.0, 2501), (77.0, 2724), (77.0, 3133), (77.0, 3395), (78.0, 2886), (79.0, 3188), (80.0, 1070), (80.0, 3206), (81.0, 838), (81.0, 1892), (81.0, 3622), (84.0, 1590), (84.0, 3370), (88.0, 1828), (89.0, 2840), (93.0, 868), (96.0, 1309), (98.0, 2198), (109.0, 3474)]

# %%
train[train.traj == 24]
# Out:
#            lat        lon  traj  seg  speed  time_left  progress
# 0    15.564935  58.414526    24    2   4.32       56.0  0.000000
# 1    15.564674  58.414425    24    2  -1.00       41.0  0.026316
# 2    15.564879  58.414508    24    2   3.75       38.0  0.052632
# 3    15.564745  58.414452    24    2   4.73       35.0  0.078947
# 4    15.564674  58.414425    24    2   5.19       35.0  0.105263
# 5    15.564578  58.414387    24    2   6.43       33.0  0.131579
# 6    15.564485  58.414349    24    2   6.84       32.0  0.157895
# 7    15.564386  58.414310    24    2   7.35       31.0  0.184211
# 8    15.564281  58.414268    24    2   7.81       30.0  0.210526
# 9    15.564164  58.414219    24    2   8.38       29.0  0.236842
# 10   15.564045  58.414173    24    2   8.79       28.0  0.263158
# 11   15.563925  58.414124    24    2   9.15       27.0  0.289474
# 12   15.563797  58.414070    24    2   9.46       26.0  0.315789
# 13   15.563655  58.414021    24    2   9.77       25.0  0.342105
# 14   15.563515  58.413971    24    2  10.03       24.0  0.368421
# 15   15.563369  58.413921    24    2  10.34       23.0  0.394737
# 16   15.563215  58.413872    24    2  10.34       22.0  0.421053
# 17   15.563064  58.413822    24    2   9.92       21.0  0.447368
# 18   15.562920  58.413776    24    2   9.98       20.0  0.473684
# 19   15.562766  58.413734    24    2  10.18       19.0  0.500000
# 20   15.562609  58.413689    24    2  10.44       18.0  0.526316
# 21   15.562439  58.413647    24    2  10.54       17.0  0.552632
# 22   15.562269  58.413601    24    2  10.95       16.0  0.578947
# 23   15.562108  58.413563    24    2  10.49       15.0  0.605263
# 24   15.561949  58.413528    24    2  10.13       14.0  0.631579
# 25   15.561786  58.413490    24    2   9.82       13.0  0.657895
# 26   15.561624  58.413456    24    2  10.03       12.0  0.684211
# 27   15.561465  58.413422    24    2  10.13       11.0  0.710526
# 28   15.561311  58.413391    24    2   9.72       10.0  0.736842
# 29   15.561156  58.413361    24    2   9.25        9.0  0.763158
# ..         ...        ...   ...  ...    ...        ...       ...
# 502  15.598313  58.407520    24   11  10.54       49.0  0.309524
# 503  15.598488  58.407536    24   11  10.44       48.0  0.333333
# 504  15.598651  58.407547    24   11  10.13       47.0  0.357143
# 505  15.598824  58.407558    24   11   9.62       46.0  0.380952
# 506  15.598989  58.407578    24   11   9.56       45.0  0.404762
# 507  15.599147  58.407597    24   11   9.15       44.0  0.428571
# 508  15.599289  58.407608    24   11   8.84       43.0  0.452381
# 509  15.599440  58.407623    24   11   8.53       42.0  0.476190
# 510  15.599582  58.407619    24   11   8.23       41.0  0.500000
# 511  15.599726  58.407635    24   11   8.17       40.0  0.523810
# 512  15.599865  58.407650    24   11   8.17       39.0  0.547619
# 513  15.600013  58.407665    24   11   8.48       38.0  0.571429
# 514  15.600168  58.407681    24   11   9.00       37.0  0.595238
# 515  15.600333  58.407700    24   11   9.51       36.0  0.619048
# 516  15.600494  58.407715    24   11   9.56       35.0  0.642857
# 517  15.600653  58.407730    24   11   9.41       34.0  0.666667
# 518  15.600807  58.407745    24   11   9.20       33.0  0.690476
# 519  15.600961  58.407761    24   11   9.05       32.0  0.714286
# 520  15.601106  58.407780    24   11   8.89       31.0  0.738095
# 521  15.601243  58.407795    24   11   8.69       30.0  0.761905
# 522  15.601385  58.407810    24   11   8.53       29.0  0.785714
# 523  15.601526  58.407825    24   11   8.33       28.0  0.809524
# 524  15.601664  58.407841    24   11   8.17       27.0  0.833333
# 525  15.601794  58.407852    24   11   8.02       26.0  0.857143
# 526  15.601929  58.407867    24   11   7.87       25.0  0.880952
# 527  15.602055  58.407879    24   11   7.71       24.0  0.904762
# 528  15.602170  58.407890    24   11   7.09       23.0  0.928571
# 529  15.602268  58.407898    24   11   5.96       22.0  0.952381
# 530  15.602353  58.407906    24   11   4.93       21.0  0.976190
# 531  15.602640  58.407917    24   11   4.21        0.0  1.000000
#
# [532 rows x 7 columns]

# %% [markdown]
# ## Utility functions
#
# The functions below are used to find the haversine distance between two GPS points and given some data and contstant `c`, find reasonable values for the length scale `l` and its variance. This is done by finding the greatest distance in the Y/X axis, and then using the biggest of those two together with the number of points and `c`.

# %%
from math import radians, cos, sin, asin, sqrt, isnan

def haversine(lon1, lat1, lon2, lat2):
    """
   Calculate the great circle distance between two points
   on the earth (specified in decimal degrees)
   """
    # convert decimal degrees to radians
    lon1, lat1, lon2, lat2 = map(radians, [lon1, lat1, lon2, lat2])
 
    # haversine formula
    dlon = lon2 - lon1
    dlat = lat2 - lat1
    a = sin(dlat/2)**2 + cos(lat1) * cos(lat2) * sin(dlon/2)**2
    c = 2 * asin(sqrt(a))
    r = 6371 # Radius of earth in kilometers
    return c * r

def calculate_l(data, c):
    N = len(data)

    dy = haversine(np.min(data.lon), 0, np.max(data.lon), 0)
    dx = haversine(0, np.min(data.lat), 0, np.max(data.lat))
    maxd = np.max([dx, dy])

    l = (maxd/N)*c
    var = 0.1
    
    return l, var

# %% [markdown]
# # Training
# Alrighty, time to train a GP. The idea here is to train on a single trajectory that embodies what we want from the synchronisation. This works because the model is used to interpolation and has consequently no need to generalise. We use both the training and support data for this model, for reasons mentioned in notebook 1.

# %%
n_trajs = train.traj.unique()
traj_n = n_trajs[2]
traj_n = 24
traj = train[train.traj == traj_n]
traj_support = support[support.traj == traj_n]
train_traj = traj.append(traj_support)
plot.traj_progress(traj)
plot.traj_segment_grid(train_traj, 'lat', 'lon', hue='progress')

# %% [markdown]
# Having found a seg_n that seems typical we can now fit GPs for each of its segments. The length scales are calculated for each segment since their geographical and speed characteristics differ somewhat.

# %%
def train_gp(data, route_n, traj_n, seg_n):
    seg = data[data.seg == seg_n]
    d_lat = train.lat.max() - train.lat.min()
    d_lon = train.lon.max() - train.lon.min()
    X = seg[['lat', 'lon']].values
    Y = seg[['progress']]
    model = gp.build_synch(X, Y, version, route_n, seg_n)
    
    l_mean, l_var = calculate_l(seg, 1500)
    print("THEM PRIORS", l_mean, l_var)
    model.model.kern.lengthscale.set_prior(GPy.priors.Gamma.from_EV(l_mean, l_var))
    model.model.kern.variance.set_prior(GPy.priors.Gamma.from_EV(0.5, 0.2))
    model.model.likelihood.variance.set_prior(GPy.priors.Gamma.from_EV(0.005, 0.00001))
    #model.model.likelihood.variance = 0.0003
    #model.model.likelihood.variance.fix()
    gp.train(model, n_restarts=5)
    print(model.model)
    return model

np.random.seed(2)
n_segs = traj.seg.unique()
gps = {seg_n: train_gp(train_traj, route_n, traj_n, seg_n) for seg_n in n_segs}
# Out:
# reconstraining parameters GP_regression.rbf.lengthscale
# reconstraining parameters GP_regression.rbf.variance
# reconstraining parameters GP_regression.Gaussian_noise.variance
# THEM PRIORS 1.888705036591462 0.1
# Optimization restart 1/5, f = -713.9434462007436
# Optimization restart 2/5, f = -713.9434461935238
# Optimization restart 3/5, f = -713.9434461998138
# Optimization restart 4/5, f = -713.9434461924619
# reconstraining parameters GP_regression.rbf.lengthscale
# Optimization restart 5/5, f = -713.9434462011066
#
# Name : GP regression
# Objective : -713.9434462011066
# Number of Parameters : 3
# Number of Optimization Parameters : 3
# Updates : True
# Parameters:
#   GP_regression.           |                  value  |  constraints  |      priors
#   rbf.variance             |     1.6217902451305457  |      +ve      |   Ga(1.2, 2.5)
#   rbf.lengthscale          |      1.570960402246986  |      +ve      |    Ga(36, 19)
#   Gaussian_noise.variance  |  0.0016524639444918708  |      +ve      |  Ga(2.5, 5e+02)
# THEM PRIORS 1.3357358752308104 0.1
# reconstraining parameters GP_regression.rbf.variance
# reconstraining parameters GP_regression.Gaussian_noise.variance
# Optimization restart 1/5, f = -1056.4934826456727
# Optimization restart 2/5, f = -1056.4934826207916
# Optimization restart 3/5, f = -1056.4934826056772
# Optimization restart 4/5, f = -1056.493482633032
# reconstraining parameters GP_regression.rbf.lengthscale
# reconstraining parameters GP_regression.rbf.variance
# reconstraining parameters GP_regression.Gaussian_noise.variance
# Optimization restart 5/5, f = -1056.493482642598
#
# Name : GP regression
# Objective : -1056.4934826456727
# Number of Parameters : 3
# Number of Optimization Parameters : 3
# Updates : True
# Parameters:
#   GP_regression.           |                  value  |  constraints  |      priors
#   rbf.variance             |     1.1744767396947828  |      +ve      |   Ga(1.2, 2.5)
#   rbf.lengthscale          |     1.3930991235797754  |      +ve      |    Ga(18, 13)
#   Gaussian_noise.variance  |  0.0009578829291323234  |      +ve      |  Ga(2.5, 5e+02)
# THEM PRIORS 1.0517525679150115 0.1
# Optimization restart 1/5, f = -505.26761710272956
# Optimization restart 2/5, f = -505.2676171034082
# Optimization restart 3/5, f = -505.2676171043748
# Optimization restart 4/5, f = -505.26761709704084
# reconstraining parameters GP_regression.rbf.lengthscale
# Optimization restart 5/5, f = -505.2676170002363
#
# Name : GP regression
# Objective : -505.2676171043748
# Number of Parameters : 3
# Number of Optimization Parameters : 3
# Updates : True
# Parameters:
#   GP_regression.           |                  value  |  constraints  |      priors
#   rbf.variance             |      1.869765755506561  |      +ve      |   Ga(1.2, 2.5)
#   rbf.lengthscale          |     1.3759800500919668  |      +ve      |    Ga(11, 11)
#   Gaussian_noise.variance  |  0.0027188230005886663  |      +ve      |  Ga(2.5, 5e+02)
# THEM PRIORS 1.0904492162769401 0.1
# reconstraining parameters GP_regression.rbf.variance
# reconstraining parameters GP_regression.Gaussian_noise.variance
# Optimization restart 1/5, f = -1376.5495518716307
# Optimization restart 2/5, f = -1376.549551884241
# Optimization restart 3/5, f = -1376.5495518905793
# Optimization restart 4/5, f = -1376.549551890385
# reconstraining parameters GP_regression.rbf.lengthscale
# Optimization restart 5/5, f = -1376.5495518712487
#
# Name : GP regression
# Objective : -1376.5495518905793
# Number of Parameters : 3
# Number of Optimization Parameters : 3
# Updates : True
# Parameters:
#   GP_regression.           |                   value  |  constraints  |      priors
#   rbf.variance             |      0.5067558192789567  |      +ve      |   Ga(1.2, 2.5)
#   rbf.lengthscale          |      0.3023356161410973  |      +ve      |    Ga(12, 11)
#   Gaussian_noise.variance  |  0.00023491659458671428  |      +ve      |  Ga(2.5, 5e+02)
# THEM PRIORS 1.5885356253966367 0.1
# reconstraining parameters GP_regression.rbf.variance
# reconstraining parameters GP_regression.Gaussian_noise.variance
# Optimization restart 1/5, f = -1216.5090027685737
# Optimization restart 2/5, f = -1216.5090027698645
# Optimization restart 3/5, f = -1216.509002769698
# Optimization restart 4/5, f = -1216.5090027696597
# reconstraining parameters GP_regression.rbf.lengthscale
# Optimization restart 5/5, f = -1216.5090027700066
#
# Name : GP regression
# Objective : -1216.5090027700066
# Number of Parameters : 3
# Number of Optimization Parameters : 3
# Updates : True
# Parameters:
#   GP_regression.           |                  value  |  constraints  |      priors
#   rbf.variance             |     0.6217819646562496  |      +ve      |   Ga(1.2, 2.5)
#   rbf.lengthscale          |     0.7390435696675022  |      +ve      |    Ga(25, 16)
#   Gaussian_noise.variance  |  0.0004789222248797019  |      +ve      |  Ga(2.5, 5e+02)
# THEM PRIORS 1.3131443310994417 0.1
# reconstraining parameters GP_regression.rbf.variance
# reconstraining parameters GP_regression.Gaussian_noise.variance
# Optimization restart 1/5, f = -1236.877788931814
# Optimization restart 2/5, f = -1236.8777893583256
# Optimization restart 3/5, f = -1236.877789359166
# Optimization restart 4/5, f = -1236.8777893590852
# reconstraining parameters GP_regression.rbf.lengthscale
# reconstraining parameters GP_regression.rbf.variance
# reconstraining parameters GP_regression.Gaussian_noise.variance
# Optimization restart 5/5, f = -1236.8777893591944
#
# Name : GP regression
# Objective : -1236.8777893591944
# Number of Parameters : 3
# Number of Optimization Parameters : 3
# Updates : True
# Parameters:
#   GP_regression.           |                  value  |  constraints  |      priors
#   rbf.variance             |    0.45352149319648294  |      +ve      |   Ga(1.2, 2.5)
#   rbf.lengthscale          |    0.46170207686443465  |      +ve      |    Ga(17, 13)
#   Gaussian_noise.variance  |  0.0006999716212818101  |      +ve      |  Ga(2.5, 5e+02)
# THEM PRIORS 2.3617548478511607 0.1
# Optimization restart 1/5, f = -552.7240952298878
# Optimization restart 2/5, f = -552.7240942813502
# Optimization restart 3/5, f = -552.7240952208163
# Optimization restart 4/5, f = -552.724095235197
# Optimization restart 5/5, f = -552.7240952290439
#
# Name : GP regression
# Objective : -552.724095235197
# Number of Parameters : 3
# Number of Optimization Parameters : 3
# Updates : True
# Parameters:
#   GP_regression.           |                 value  |  constraints  |      priors
#   rbf.variance             |     2.030587320413176  |      +ve      |   Ga(1.2, 2.5)
#   rbf.lengthscale          |    1.8071744921638095  |      +ve      |    Ga(56, 24)
#   Gaussian_noise.variance  |  0.001392625498046573  |      +ve      |  Ga(2.5, 5e+02)
# THEM PRIORS 1.7021767641342365 0.1
# reconstraining parameters GP_regression.rbf.lengthscale
# reconstraining parameters GP_regression.rbf.variance
# reconstraining parameters GP_regression.Gaussian_noise.variance
# Optimization restart 1/5, f = -4450.331385212807
# Optimization restart 2/5, f = -4450.3313852146775
# Optimization restart 3/5, f = -4450.33138472677
# Optimization restart 4/5, f = -4450.331385210569
# Optimization restart 5/5, f = -4450.331385208164
# reconstraining parameters GP_regression.rbf.lengthscale
# reconstraining parameters GP_regression.rbf.variance
# Name : GP regression
# Objective : -4450.3313852146775
# Number of Parameters : 3
# Number of Optimization Parameters : 3
# Updates : True
# Parameters:
#   GP_regression.           |                  value  |  constraints  |      priors
#   rbf.variance             |     0.5185120484044824  |      +ve      |   Ga(1.2, 2.5)
#   rbf.lengthscale          |     0.4822679859884591  |      +ve      |    Ga(29, 17)
#   Gaussian_noise.variance  |  5.895009819266276e-05  |      +ve      |  Ga(2.5, 5e+02)
# THEM PRIORS 2.2229759334898946 0.1
# reconstraining parameters GP_regression.Gaussian_noise.variance
# Optimization restart 1/5, f = -765.2739567339507
# Optimization restart 2/5, f = -765.2739567377583
# Optimization restart 3/5, f = -765.2739567377081
# Optimization restart 4/5, f = -765.2739567375611
# reconstraining parameters GP_regression.rbf.lengthscale
# reconstraining parameters GP_regression.rbf.variance
# Optimization restart 5/5, f = -765.2739567377171
#
# Name : GP regression
# Objective : -765.2739567377583
# Number of Parameters : 3
# Number of Optimization Parameters : 3
# Updates : True
# Parameters:
#   GP_regression.           |                  value  |  constraints  |      priors
#   rbf.variance             |     1.3663536743389173  |      +ve      |   Ga(1.2, 2.5)
#   rbf.lengthscale          |      1.067002911234051  |      +ve      |    Ga(49, 22)
#   Gaussian_noise.variance  |  0.0017979696012429232  |      +ve      |  Ga(2.5, 5e+02)
# THEM PRIORS 2.1762054792836008 0.1
# reconstraining parameters GP_regression.Gaussian_noise.variance
# Optimization restart 1/5, f = -781.8698480517106
# Optimization restart 2/5, f = -781.8698480439217
# Optimization restart 3/5, f = -792.4293648511614
# Optimization restart 4/5, f = -792.4293648478697
# Optimization restart 5/5, f = -781.8698480246659
#
# Name : GP regression
# Objective : -792.4293648511614
# Number of Parameters : 3
# Number of Optimization Parameters : 3
# Updates : True
# Parameters:
#   GP_regression.           |                  value  |  constraints  |      priors
#   rbf.variance             |     1.0494939171837574  |      +ve      |   Ga(1.2, 2.5)
#   rbf.lengthscale          |     1.0293982527003593  |      +ve      |    Ga(47, 22)
#   Gaussian_noise.variance  |  0.0013389615714861794  |      +ve      |  Ga(2.5, 5e+02)

# %% [markdown]
# ## Plotting synched trajectories
# Below is a plot of the GPs and the synchronisation of some unseen new trajectories to test its robustness. The goal is to have the lines of the contour plots to be orthogonal of the bus progress. We see that the synchronisation is quite robust, and so we save the trajectories.
#
# There is still improvements to be made but it's hard to figure out how it can be made better.

# %%
def synch_data(synch_gp, data):
    latlon = ['lat', 'lon']
    X = data[latlon].values
    tau, _var = gp.predict(synch_gp, X)
    synched_data = data.copy()
    synched_data['tau'] = tau
    synched_data.drop(xy, axis=1)
    return synched_data

test = pd.read_pickle('test.pkl')
print(len(test))
n_segs = test.seg.unique()
_fig, axs = plt.subplots(nrows=len(n_segs), ncols=2, figsize=(12, int(12*len(n_segs))))
for i, seg_n, model in zip(range(len(n_segs)), n_segs, gps.values()):
    seg = test[test.seg == seg_n]
    #print(len(test))
    #print('####SEG', seg)
    X = seg[['lat', 'lon']].values
    tau, _var = gp.predict(gps[int(seg_n)], X)
    df = pd.DataFrame({'Prediction': tau.T[0], 'Truth': seg.progress})
    model.model.plot(ax=axs[i, 0])
    axs[i, 0].set_aspect('equal', 'datalim')
    sns.scatterplot(data=df, x='Truth', y='Prediction', ax=axs[i, 1])
    axs[i, 1].set_aspect('equal', 'datalim')
# Out:
# 19699
#  C:\Users\sebas\Anaconda3\envs\gpflow\lib\site-packages\matplotlib\contour.py:1000: UserWarning:The following kwargs were not used by contour: 'label', 'linewidth'
#  C:\Users\sebas\Anaconda3\envs\gpflow\lib\site-packages\matplotlib\contour.py:1000: UserWarning:The following kwargs were not used by contour: 'label', 'linewidth'
#  C:\Users\sebas\Anaconda3\envs\gpflow\lib\site-packages\matplotlib\contour.py:1000: UserWarning:The following kwargs were not used by contour: 'label', 'linewidth'
#  C:\Users\sebas\Anaconda3\envs\gpflow\lib\site-packages\matplotlib\contour.py:1000: UserWarning:The following kwargs were not used by contour: 'label', 'linewidth'
#  C:\Users\sebas\Anaconda3\envs\gpflow\lib\site-packages\matplotlib\contour.py:1000: UserWarning:The following kwargs were not used by contour: 'label', 'linewidth'
#  C:\Users\sebas\Anaconda3\envs\gpflow\lib\site-packages\matplotlib\contour.py:1000: UserWarning:The following kwargs were not used by contour: 'label', 'linewidth'
#  C:\Users\sebas\Anaconda3\envs\gpflow\lib\site-packages\matplotlib\contour.py:1000: UserWarning:The following kwargs were not used by contour: 'label', 'linewidth'
#  C:\Users\sebas\Anaconda3\envs\gpflow\lib\site-packages\matplotlib\contour.py:1000: UserWarning:The following kwargs were not used by contour: 'label', 'linewidth'
#  C:\Users\sebas\Anaconda3\envs\gpflow\lib\site-packages\matplotlib\contour.py:1000: UserWarning:The following kwargs were not used by contour: 'label', 'linewidth'
#  C:\Users\sebas\Anaconda3\envs\gpflow\lib\site-packages\matplotlib\contour.py:1000: UserWarning:The following kwargs were not used by contour: 'label', 'linewidth'

# %%
for model in gps.values():
     gp.save(model)

# %% [markdown]
# A final test of the load functions and plotting of (training) predictions

# %%
traj = train[train.traj == traj_n]
_fig, ax = plt.subplots(nrows=len(n_segs), ncols=1, figsize=(6, int(6*len(n_segs))))
for i, seg_n in zip(range(len(n_segs)), n_segs):
    seg = traj[traj.seg == seg_n]
    sgp = gp.load_synch(route_n, seg_n, version=version)
    X = seg[['lat', 'lon']].values
    mean, _var = gp.predict(sgp, X)
    df = pd.DataFrame({'pred': mean.T[0], 'X': range(X.shape[0])})
    sns.scatterplot(data=df, x='X', y='pred', ax=ax[i])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-29-05f2c3b1cdf6> in <module>
#       3 for i, seg_n in zip(range(len(n_segs)), n_segs):
#       4     seg = traj[traj.seg == seg_n]
# ----> 5     sgp = gp.load_synch(route_n, seg_n, version=version)
#       6     X = seg[['lat', 'lon']].values
#       7     mean, _var = gp.predict(sgp, X)
#
# ~\Documents\code\tdde19\det-ar-lugnt\GP\gp_gpy.py in load_synch(route_n, seg_n, version)
#     159
#     160 def load_synch(route_n: int, seg_n: int, version: str) -> GP:
# --> 161     return load('synch-' + str(version), route_n, 0, seg_n)
#     162
#     163 def load(name: str,
#
# ~\Documents\code\tdde19\det-ar-lugnt\GP\gp_gpy.py in load(name, route_n, traj_n, seg_n)
#     172     data_path  = path + __gp_data_file(route_n, traj_n, seg_n)
#     173     model_path = path + __gp_model_file(route_n, traj_n, seg_n)
# --> 174     X, Y = load_data(data_path)
#     175     params = load_params(model_path)
#     176     gp = build(X, Y, name, route_n, traj_n, seg_n)
#
# ~\Documents\code\tdde19\det-ar-lugnt\GP\gp_gpy.py in load_data(path)
#     148
#     149 def load_data(path):
# --> 150     with open(path, 'rb') as handle:
#     151         X, Y = pickle.load(handle)
#     152     return X, Y
#
# FileNotFoundError: [Errno 2] No such file or directory: './gps/synch-3/3.0.2.pkl'
