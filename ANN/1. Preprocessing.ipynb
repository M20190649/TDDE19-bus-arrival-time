# %% [markdown]
# # Label each row with features required to run ANN notebooks
#
# The new features are:
# * The time left until next bus stop (seconds)
# * The time it takes to travel the full segment (seconds)
# * The time from the start of the journey to the start of the current segment (seconds)

# %%
#import tensorflow as tf
#from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt
import pandas as pds
import datetime as dt
import time
from datetime import datetime

# %%
df = pds.read_csv('../../bus203_all.csv')
df.head(1000)
# Out:
#      Unnamed: 0                          timestamp                  event  \
# 0             0  2018-02-16T04:48:40.0000000+01:00    JourneyStartedEvent
# 1             1  2018-02-16T04:48:40.0000000+01:00  ObservedPositionEvent
# 2             2  2018-02-16T04:48:40.0000000+01:00           ArrivedEvent
# 3             3  2018-02-16T04:48:41.0000000+01:00  ObservedPositionEvent
# 4             4  2018-02-16T04:48:42.0000000+01:00  ObservedPositionEvent
# 5             5  2018-02-16T04:48:43.0000000+01:00  ObservedPositionEvent
# 6             6  2018-02-16T04:48:44.0000000+01:00  ObservedPositionEvent
# 7             7  2018-02-16T04:48:45.0000000+01:00  ObservedPositionEvent
# 8             8  2018-02-16T04:48:46.0000000+01:00  ObservedPositionEvent
# 9             9  2018-02-16T04:48:47.0000000+01:00  ObservedPositionEvent
# 10           10  2018-02-16T04:48:48.0000000+01:00  ObservedPositionEvent
# 11           11  2018-02-16T04:48:49.0000000+01:00  ObservedPositionEvent
# 12           12  2018-02-16T04:48:50.0000000+01:00  ObservedPositionEvent
# 13           13  2018-02-16T04:48:51.0000000+01:00  ObservedPositionEvent
# 14           14  2018-02-16T04:48:52.0000000+01:00  ObservedPositionEvent
# 15           15  2018-02-16T04:48:53.0000000+01:00  ObservedPositionEvent
# 16           16  2018-02-16T04:48:54.0000000+01:00  ObservedPositionEvent
# 17           17  2018-02-16T04:48:54.0000000+01:00          DepartedEvent
# 18           18  2018-02-16T04:48:55.0000000+01:00  ObservedPositionEvent
# 19           19  2018-02-16T04:48:56.0000000+01:00  ObservedPositionEvent
# 20           20  2018-02-16T04:48:57.0000000+01:00  ObservedPositionEvent
# 21           21  2018-02-16T04:48:58.0000000+01:00  ObservedPositionEvent
# 22           22  2018-02-16T04:48:59.0000000+01:00  ObservedPositionEvent
# 23           23  2018-02-16T04:49:00.0000000+01:00  ObservedPositionEvent
# 24           24  2018-02-16T04:49:01.0000000+01:00  ObservedPositionEvent
# 25           25  2018-02-16T04:49:01.0000000+01:00            ExitedEvent
# 26           26  2018-02-16T04:49:02.0000000+01:00  ObservedPositionEvent
# 27           27  2018-02-16T04:49:03.0000000+01:00  ObservedPositionEvent
# 28           28  2018-02-16T04:49:04.0000000+01:00  ObservedPositionEvent
# 29           29  2018-02-16T04:49:05.0000000+01:00  ObservedPositionEvent
# ..          ...                                ...                    ...
# 970         288  2018-02-16T05:20:37.0000000+01:00  ObservedPositionEvent
# 971         289  2018-02-16T05:20:38.0000000+01:00  ObservedPositionEvent
# 972         290  2018-02-16T05:20:38.0000000+01:00          DepartedEvent
# 973         291  2018-02-16T05:20:39.0000000+01:00  ObservedPositionEvent
# 974         292  2018-02-16T05:20:40.0000000+01:00  ObservedPositionEvent
# 975         293  2018-02-16T05:20:41.0000000+01:00  ObservedPositionEvent
# 976         294  2018-02-16T05:20:42.0000000+01:00  ObservedPositionEvent
# 977         295  2018-02-16T05:20:43.0000000+01:00            ExitedEvent
# 978         296  2018-02-16T05:20:43.0000000+01:00  ObservedPositionEvent
# 979         297  2018-02-16T05:20:44.0000000+01:00  ObservedPositionEvent
# 980         298  2018-02-16T05:20:45.0000000+01:00  ObservedPositionEvent
# 981         299  2018-02-16T05:20:46.0000000+01:00  ObservedPositionEvent
# 982         300  2018-02-16T05:20:47.0000000+01:00  ObservedPositionEvent
# 983         301  2018-02-16T05:20:48.0000000+01:00  ObservedPositionEvent
# 984         302  2018-02-16T05:20:49.0000000+01:00  ObservedPositionEvent
# 985         303  2018-02-16T05:20:50.0000000+01:00  ObservedPositionEvent
# 986         304  2018-02-16T05:20:51.0000000+01:00  ObservedPositionEvent
# 987         305  2018-02-16T05:20:52.0000000+01:00  ObservedPositionEvent
# 988         306  2018-02-16T05:20:53.0000000+01:00  ObservedPositionEvent
# 989         307  2018-02-16T05:20:54.0000000+01:00  ObservedPositionEvent
# 990         308  2018-02-16T05:20:55.0000000+01:00  ObservedPositionEvent
# 991         309  2018-02-16T05:20:56.0000000+01:00  ObservedPositionEvent
# 992         310  2018-02-16T05:20:57.0000000+01:00  ObservedPositionEvent
# 993         311  2018-02-16T05:20:58.0000000+01:00  ObservedPositionEvent
# 994         312  2018-02-16T05:20:59.0000000+01:00  ObservedPositionEvent
# 995         313  2018-02-16T05:21:00.0000000+01:00  ObservedPositionEvent
# 996         314  2018-02-16T05:21:01.0000000+01:00  ObservedPositionEvent
# 997         315  2018-02-16T05:21:02.0000000+01:00  ObservedPositionEvent
# 998         316  2018-02-16T05:21:03.0000000+01:00  ObservedPositionEvent
# 999         317  2018-02-16T05:21:04.0000000+01:00  ObservedPositionEvent
#
#      vehicle_id  line  longitude   latitude   direction  speed  \
# 0          5432   203  58.414238  15.571015   -1.000000  -1.00
# 1          5432     0  58.414238  15.571015  147.300003   0.00
# 2          5432   203  58.414238  15.571015   -1.000000  -1.00
# 3          5432     0  58.414246  15.571012  147.300003   0.00
# 4          5432     0  58.414249  15.571008  147.300003   0.00
# 5          5432     0  58.414257  15.571004  147.300003   0.00
# 6          5432     0  58.414257  15.571006  147.300003   0.00
# 7          5432     0  58.414261  15.571008  147.300003   0.00
# 8          5432     0  58.414261  15.571010  147.300003   0.00
# 9          5432     0  58.414261  15.571012  147.300003   0.00
# 10         5432     0  58.414265  15.571014  147.300003   0.00
# 11         5432     0  58.414268  15.571015  147.300003   0.00
# 12         5432     0  58.414268  15.571015  147.300003   0.00
# 13         5432     0  58.414268  15.571015  147.300003   0.00
# 14         5432     0  58.414268  15.571015  147.300003   0.00
# 15         5432     0  58.414268  15.571014  147.300003   0.00
# 16         5432     0  58.414268  15.571014  147.300003   0.00
# 17         5432   203  58.414196  15.571187   -1.000000  -1.00
# 18         5432     0  58.414265  15.571016  147.300003   0.41
# 19         5432     0  58.414257  15.571025  140.300003   0.77
# 20         5432     0  58.414249  15.571035  139.889999   0.97
# 21         5432     0  58.414238  15.571051  136.600006   1.18
# 22         5432     0  58.414230  15.571072  134.889999   1.49
# 23         5432     0  58.414215  15.571098  128.199997   1.69
# 24         5432     0  58.414204  15.571137  118.800003   2.31
# 25         5432   203  58.414196  15.571187   -1.000000  -1.00
# 26         5432     0  58.414196  15.571187  106.800003   2.57
# 27         5432     0  58.414196  15.571241   94.000000   2.72
# 28         5432     0  58.414200  15.571293   80.690002   2.77
# 29         5432     0  58.414211  15.571343   68.690002   2.77
# ..          ...   ...        ...        ...         ...    ...
# 970        5490     0  58.413147  15.560012  243.600006   0.00
# 971        5490     0  58.413147  15.560011  243.600006   0.00
# 972        5490   203  58.413055  15.559770   -1.000000  -1.00
# 973        5490     0  58.413147  15.560006  242.199997   0.82
# 974        5490     0  58.413136  15.559980  235.500000   1.64
# 975        5490     0  58.413124  15.559943  232.199997   2.52
# 976        5490     0  58.413101  15.559896  230.399994   3.29
# 977        5490   203  58.413055  15.559770   -1.000000  -1.00
# 978        5490     0  58.413078  15.559837  232.699997   4.16
# 979        5490     0  58.413055  15.559770  236.100006   4.62
# 980        5490     0  58.413025  15.559676  239.300003   5.65
# 981        5490     0  58.413002  15.559578  241.800003   6.22
# 982        5490     0  58.412979  15.559474  243.100006   6.84
# 983        5490     0  58.412945  15.559361  242.699997   7.56
# 984        5490     0  58.412907  15.559242  240.699997   7.92
# 985        5490     0  58.412868  15.559112  240.699997   8.23
# 986        5490     0  58.412827  15.558981  239.199997   8.74
# 987        5490     0  58.412785  15.558849  237.199997   9.46
# 988        5490     0  58.412731  15.558702  236.600006  10.13
# 989        5490     0  58.412678  15.558544  236.300003  10.64
# 990        5490     0  58.412617  15.558388  234.399994  11.21
# 991        5490     0  58.412560  15.558235  234.399994  11.06
# 992        5490     0  58.412498  15.558080  233.000000  11.06
# 993        5490     0  58.412434  15.557926  231.000000  11.00
# 994        5490     0  58.412373  15.557781  231.699997  10.75
# 995        5490     0  58.412312  15.557648  229.500000  10.80
# 996        5490     0  58.412243  15.557509  228.600006  10.75
# 997        5490     0  58.412178  15.557370  226.500000  10.59
# 998        5490     0  58.412109  15.557242  224.000000  10.49
# 999        5490     0  58.412045  15.557127  221.699997  10.44
#
#                             station  journey_number  segment_number
# 0                               NaN               1               1
# 1                               NaN               1               1
# 2    Rydsv\xe4gens \xe4ndh\xe5llpl.               1               1
# 3                               NaN               1               1
# 4                               NaN               1               1
# 5                               NaN               1               1
# 6                               NaN               1               1
# 7                               NaN               1               1
# 8                               NaN               1               1
# 9                               NaN               1               1
# 10                              NaN               1               1
# 11                              NaN               1               1
# 12                              NaN               1               1
# 13                              NaN               1               1
# 14                              NaN               1               1
# 15                              NaN               1               1
# 16                              NaN               1               1
# 17   Rydsv\xe4gens \xe4ndh\xe5llpl.               1               1
# 18                              NaN               1               1
# 19                              NaN               1               1
# 20                              NaN               1               1
# 21                              NaN               1               1
# 22                              NaN               1               1
# 23                              NaN               1               1
# 24                              NaN               1               1
# 25   Rydsv\xe4gens \xe4ndh\xe5llpl.               1               1
# 26                              NaN               1               1
# 27                              NaN               1               1
# 28                              NaN               1               1
# 29                              NaN               1               1
# ..                              ...             ...             ...
# 970                             NaN               2               3
# 971                             NaN               2               3
# 972               Als\xe4ttersgatan               2               3
# 973                             NaN               2               3
# 974                             NaN               2               3
# 975                             NaN               2               3
# 976                             NaN               2               3
# 977               Als\xe4ttersgatan               2               3
# 978                             NaN               2               3
# 979                             NaN               2               3
# 980                             NaN               2               3
# 981                             NaN               2               3
# 982                             NaN               2               3
# 983                             NaN               2               3
# 984                             NaN               2               3
# 985                             NaN               2               3
# 986                             NaN               2               3
# 987                             NaN               2               3
# 988                             NaN               2               3
# 989                             NaN               2               3
# 990                             NaN               2               3
# 991                             NaN               2               3
# 992                             NaN               2               3
# 993                             NaN               2               3
# 994                             NaN               2               3
# 995                             NaN               2               3
# 996                             NaN               2               3
# 997                             NaN               2               3
# 998                             NaN               2               3
# 999                             NaN               2               3
#
# [1000 rows x 12 columns]

# %% [markdown]
# Ignore entries that are not `ObservedPositionEvent`

# %%
df = df[df['event'] == "ObservedPositionEvent"]

# %% [markdown]
# This leaves the indexes of rows untouched, reset.

# %%
df = df.reset_index().drop(columns=['index'])

# %% [markdown]
# A triple loop as it seems, but it is only to finally group rows from each individual segment from every journey. Should be linear in time, as the innermost loop will do all executions and every row is visited once. This only took ~50% of my 8GB of RAM but took ~30 minutes to run.

# %%
time_left = pds.DataFrame(np.zeros(len(df.index)), columns=['time_left'])
segment_time = pds.DataFrame(np.zeros(len(df.index)), columns=['segment_time'])
tsjs = pds.DataFrame(np.zeros(len(df.index)), columns=['tsjs'])

t0 = time.time()

for j, df_j in df.groupby('journey_number'):
    journey_start = pds.to_datetime(df_j['timestamp'].iloc[0])
    for k, df_s in df_j.groupby('segment_number'):
        end_time = pds.to_datetime(df_s['timestamp'].iloc[-1])
        start_time = pds.to_datetime(df_s['timestamp'].iloc[0])
        for idx, row in df_s.iterrows():
            # The subtraction returns timedelta between the two timestamp objects
            # and total seconds convert the pandas datetime object to seconds
            time_left.iloc[idx] = (end_time - pds.to_datetime(row['timestamp'])).total_seconds()
            segment_time.iloc[idx] = (end_time - start_time).total_seconds()
            tsjs.iloc[idx] = (start_time - journey_start).total_seconds()

elapsed = time.time() - t0
print("Data processed in", elapsed, " seconds")
# Out:
# Data processed in 2117.0965390205383  seconds

# %% [markdown]
# Add new features to dataframe `df`

# %%
data = pds.concat([df, time_left,segment_time, tsjs], axis=1)
data.head()
# Out:
#    Unnamed: 0                          timestamp                  event  \
# 0           1  2018-02-16T04:48:40.0000000+01:00  ObservedPositionEvent
# 1           3  2018-02-16T04:48:41.0000000+01:00  ObservedPositionEvent
# 2           4  2018-02-16T04:48:42.0000000+01:00  ObservedPositionEvent
# 3           5  2018-02-16T04:48:43.0000000+01:00  ObservedPositionEvent
# 4           6  2018-02-16T04:48:44.0000000+01:00  ObservedPositionEvent
#
#    vehicle_id  line  longitude   latitude   direction  speed station  \
# 0        5432     0  58.414238  15.571015  147.300003    0.0     NaN
# 1        5432     0  58.414246  15.571012  147.300003    0.0     NaN
# 2        5432     0  58.414249  15.571008  147.300003    0.0     NaN
# 3        5432     0  58.414257  15.571004  147.300003    0.0     NaN
# 4        5432     0  58.414257  15.571006  147.300003    0.0     NaN
#
#    journey_number  segment_number  time_left  segment_time  tsjs
# 0               1               1       71.0          71.0   0.0
# 1               1               1       70.0          71.0   0.0
# 2               1               1       69.0          71.0   0.0
# 3               1               1       68.0          71.0   0.0
# 4               1               1       67.0          71.0   0.0

# %% [markdown]
# Renaming some columns to keep them similar to the GP model for easier understanding.

# %%
data.rename(columns={'longitude': 'lon', 'latitude': 'lat', 'segment_number': 'seg', 'journey_number': 'journey'}, inplace=True)
data.head()
# Out:
#    Unnamed: 0                          timestamp                  event  \
# 0           1  2018-02-16T04:48:40.0000000+01:00  ObservedPositionEvent
# 1           3  2018-02-16T04:48:41.0000000+01:00  ObservedPositionEvent
# 2           4  2018-02-16T04:48:42.0000000+01:00  ObservedPositionEvent
# 3           5  2018-02-16T04:48:43.0000000+01:00  ObservedPositionEvent
# 4           6  2018-02-16T04:48:44.0000000+01:00  ObservedPositionEvent
#
#    vehicle_id  line        lon        lat   direction  speed station  journey  \
# 0        5432     0  58.414238  15.571015  147.300003    0.0     NaN        1
# 1        5432     0  58.414246  15.571012  147.300003    0.0     NaN        1
# 2        5432     0  58.414249  15.571008  147.300003    0.0     NaN        1
# 3        5432     0  58.414257  15.571004  147.300003    0.0     NaN        1
# 4        5432     0  58.414257  15.571006  147.300003    0.0     NaN        1
#
#    seg  time_left  segment_time  tsjs
# 0    1       71.0          71.0   0.0
# 1    1       70.0          71.0   0.0
# 2    1       69.0          71.0   0.0
# 3    1       68.0          71.0   0.0
# 4    1       67.0          71.0   0.0

# %% [markdown]
# ... and save it.

# %%
data.to_pickle('ANN_dataset.pkl')
